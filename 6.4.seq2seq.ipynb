# %%
import tensorflow as tf
import numpy as np
import os

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
from google.colab import files
import sys
sys.path.append('/content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code')
# !pip install konlpy
from preprocess import *
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.7/dist-packages (0.5.2)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.2.1)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (from konlpy) (0.4.4)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: beautifulsoup4==4.6.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.6.0)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)

# %%
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string], '')
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

# %%
DATA_IN_PATH = '/content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_in'

DATA_OUT_PATH = '/content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_out'
TRAIN_INPUTS = 'train_inputs.npy'
TRAIN_OUTPUTS = 'train_outputs.npy'
TRAIN_TARGETS = 'train_targets.npy'
DATA_CONFIGS = 'data_configs.json'

# %%
SEED_NUM = 1234
tf.random.set_seed(SEED_NUM)

# %%
index_inputs = np.load(open(DATA_IN_PATH + TRAIN_INPUTS, 'rb'))
index_outputs = np.load(open(DATA_IN_PATH + TRAIN_OUTPUTS , 'rb'))
index_targets = np.load(open(DATA_IN_PATH + TRAIN_TARGETS , 'rb'))
prepro_configs = json.load(open(DATA_IN_PATH + DATA_CONFIGS, 'r'))

# %%
# Show length
print(len(index_inputs),  len(index_outputs), len(index_targets))
# Out:
# 20 20 20

# %%
MODEL_NAME = 'seq2seq_kor'
BATCH_SIZE = 2
MAX_SEQUENCE = 25
EPOCH = 30
UNITS = 1024
EMBEDDING_DIM = 256
VALIDATION_SPLIT = 0.1 

char2idx = prepro_configs['char2idx']
idx2char = prepro_configs['idx2char']
std_index = prepro_configs['std_symbol']
end_index = prepro_configs['end_symbol']
vocab_size = prepro_configs['vocab_size']

# %% [markdown]
# 모델

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.vocab_size = vocab_size 
        self.embedding_dim = embedding_dim          
        
        self.embedding = tf.keras.layers.Embedding(self.vocab_size, self.embedding_dim)
        self.gru = tf.keras.layers.GRU(self.enc_units, # 결과 차원의 크기
                                       return_sequences=True, # 각 시퀀스마다 출력을 반환할지 여부
                                       return_state=True, # 마지막 상태값의 반환 여부
                                       recurrent_initializer='glorot_uniform') # 초기값을 무엇으로 할 것인지. 이전 노드와 다음 노드의 개수에 의존하는 방법

    def call(self, x, hidden):
        x = self.embedding(x)
        output, state = self.gru(x, initial_state = hidden)
        return output, state

    def initialize_hidden_state(self, inp):
        return tf.zeros((tf.shape(inp)[0], self.enc_units)) # 배치 크기를 받아 순환신경망 초기에 사용될 은닉 상태를 만든다

# %%
class BahdanauAttention(tf.keras.layers.Layer):
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)

    def call(self, query, values):
        hidden_with_time_axis = tf.expand_dims(query, 1)

        score = self.V(tf.nn.tanh(
            self.W1(values) + self.W2(hidden_with_time_axis)))

        attention_weights = tf.nn.softmax(score, axis=1)

        context_vector = attention_weights * values
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %%
class Decoder(tf.keras.layers.Layer):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()
        
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.vocab_size = vocab_size 
        self.embedding_dim = embedding_dim  
        
        self.embedding = tf.keras.layers.Embedding(self.vocab_size, self.embedding_dim)
        self.gru = tf.keras.layers.GRU(self.dec_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
        self.fc = tf.keras.layers.Dense(self.vocab_size)

        self.attention = BahdanauAttention(self.dec_units)
        
    def call(self, x, hidden, enc_output):
        context_vector, attention_weights = self.attention(hidden, enc_output)

        x = self.embedding(x)

        x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

        output, state = self.gru(x)
        output = tf.reshape(output, (-1, output.shape[2]))
            
        x = self.fc(output)
        
        return x, state, attention_weights

# %%
optimizer = tf.keras.optimizers.Adam()

loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='accuracy')

def loss(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)
    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask
    return tf.reduce_mean(loss_)

def accuracy(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    mask = tf.expand_dims(tf.cast(mask, dtype=pred.dtype), axis=-1)
    pred *= mask    
    acc = train_accuracy(real, pred)

    return tf.reduce_mean(acc)

# %%
class seq2seq(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, dec_units, batch_sz, end_token_idx=2):    
        super(seq2seq, self).__init__()
        self.end_token_idx = end_token_idx
        self.encoder = Encoder(vocab_size, embedding_dim, enc_units, batch_sz) 
        self.decoder = Decoder(vocab_size, embedding_dim, dec_units, batch_sz) 

    def call(self, x):
        inp, tar = x
        
        enc_hidden = self.encoder.initialize_hidden_state(inp)
        enc_output, enc_hidden = self.encoder(inp, enc_hidden)

        dec_hidden = enc_hidden

        predict_tokens = list()
        for t in range(0, tar.shape[1]):
            dec_input = tf.dtypes.cast(tf.expand_dims(tar[:, t], 1), tf.float32) 
            predictions, dec_hidden, _ = self.decoder(dec_input, dec_hidden, enc_output)
            predict_tokens.append(tf.dtypes.cast(predictions, tf.float32))   
        return tf.stack(predict_tokens, axis=1)
    
    def inference(self, x):
        inp  = x

        enc_hidden = self.encoder.initialize_hidden_state(inp)
        enc_output, enc_hidden = self.encoder(inp, enc_hidden)

        dec_hidden = enc_hidden
        
        dec_input = tf.expand_dims([char2idx[std_index]], 1)
        
        predict_tokens = list()
        for t in range(0, MAX_SEQUENCE):
            predictions, dec_hidden, _ = self.decoder(dec_input, dec_hidden, enc_output)
            predict_token = tf.argmax(predictions[0])
            
            if predict_token == self.end_token_idx:
                break
            
            predict_tokens.append(predict_token)
            dec_input = tf.dtypes.cast(tf.expand_dims([predict_token], 0), tf.float32)   
            
        return tf.stack(predict_tokens, axis=0).numpy()

# %%
model = seq2seq(vocab_size, EMBEDDING_DIM, UNITS, UNITS, BATCH_SIZE, char2idx[end_index])
model.compile(loss=loss, optimizer=tf.keras.optimizers.Adam(1e-3), metrics=[accuracy])
#model.run_eagerly = True

# %%
PATH = DATA_OUT_PATH + MODEL_NAME
if not(os.path.isdir(PATH)):
        os.makedirs(os.path.join(PATH))
        
checkpoint_path = DATA_OUT_PATH + MODEL_NAME + '/weights.h5'
    
cp_callback = ModelCheckpoint(
    checkpoint_path, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=True)

earlystop_callback = EarlyStopping(monitor='val_accuracy', min_delta=0.0001, patience=10)

history = model.fit([index_inputs, index_outputs], index_targets,
                    batch_size=BATCH_SIZE, epochs=EPOCH,
                    validation_split=VALIDATION_SPLIT, callbacks=[earlystop_callback, cp_callback])
# Out:
# Epoch 1/30
# 9/9 [==============================] - 65s 5s/step - loss: 1.8606 - accuracy: 0.8170 - val_loss: 1.0175 - val_accuracy: 0.8540
#
# Epoch 00001: val_accuracy improved from -inf to 0.85400, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 2/30
# 9/9 [==============================] - 36s 4s/step - loss: 1.1595 - accuracy: 0.8527 - val_loss: 0.8336 - val_accuracy: 0.8520
#
# Epoch 00002: val_accuracy did not improve from 0.85400
# Epoch 3/30
# 9/9 [==============================] - 40s 5s/step - loss: 0.8282 - accuracy: 0.8505 - val_loss: 0.5856 - val_accuracy: 0.8513
#
# Epoch 00003: val_accuracy did not improve from 0.85400
# Epoch 4/30
# 9/9 [==============================] - 35s 4s/step - loss: 0.6802 - accuracy: 0.8526 - val_loss: 0.6052 - val_accuracy: 0.8530
#
# Epoch 00004: val_accuracy did not improve from 0.85400
# Epoch 5/30
# 9/9 [==============================] - 36s 4s/step - loss: 0.6722 - accuracy: 0.8533 - val_loss: 0.5983 - val_accuracy: 0.8540
#
# Epoch 00005: val_accuracy did not improve from 0.85400
# Epoch 6/30
# 9/9 [==============================] - 36s 4s/step - loss: 0.7386 - accuracy: 0.8534 - val_loss: 0.5710 - val_accuracy: 0.8547
#
# Epoch 00006: val_accuracy improved from 0.85400 to 0.85467, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 7/30
# 9/9 [==============================] - 38s 4s/step - loss: 0.8664 - accuracy: 0.8547 - val_loss: 0.5781 - val_accuracy: 0.8549
#
# Epoch 00007: val_accuracy improved from 0.85467 to 0.85486, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 8/30
# 9/9 [==============================] - 37s 4s/step - loss: 0.6818 - accuracy: 0.8546 - val_loss: 0.5767 - val_accuracy: 0.8553
#
# Epoch 00008: val_accuracy improved from 0.85486 to 0.85525, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 9/30
# 9/9 [==============================] - 36s 4s/step - loss: 0.7076 - accuracy: 0.8548 - val_loss: 0.5708 - val_accuracy: 0.8556
#
# Epoch 00009: val_accuracy improved from 0.85525 to 0.85556, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 10/30
# 9/9 [==============================] - 36s 4s/step - loss: 0.6145 - accuracy: 0.8562 - val_loss: 0.5328 - val_accuracy: 0.8558
#
# Epoch 00010: val_accuracy improved from 0.85556 to 0.85580, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 11/30
# 9/9 [==============================] - 36s 4s/step - loss: 0.7209 - accuracy: 0.8552 - val_loss: 0.5278 - val_accuracy: 0.8562
#
# Epoch 00011: val_accuracy improved from 0.85580 to 0.85618, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 12/30
# 9/9 [==============================] - 36s 4s/step - loss: 0.6142 - accuracy: 0.8563 - val_loss: 0.5236 - val_accuracy: 0.8567
#
# Epoch 00012: val_accuracy improved from 0.85618 to 0.85667, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 13/30
# 9/9 [==============================] - 36s 4s/step - loss: 0.5741 - accuracy: 0.8570 - val_loss: 0.5724 - val_accuracy: 0.8571
#
# Epoch 00013: val_accuracy improved from 0.85667 to 0.85708, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 14/30
# 9/9 [==============================] - 35s 4s/step - loss: 0.5897 - accuracy: 0.8572 - val_loss: 0.4755 - val_accuracy: 0.8573
#
# Epoch 00014: val_accuracy improved from 0.85708 to 0.85729, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 15/30
# 9/9 [==============================] - 36s 4s/step - loss: 0.5871 - accuracy: 0.8575 - val_loss: 0.5523 - val_accuracy: 0.8575
#
# Epoch 00015: val_accuracy improved from 0.85729 to 0.85747, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 16/30
# 9/9 [==============================] - 36s 4s/step - loss: 0.5431 - accuracy: 0.8578 - val_loss: 0.5391 - val_accuracy: 0.8576
#
# Epoch 00016: val_accuracy improved from 0.85747 to 0.85763, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 17/30
# 9/9 [==============================] - 36s 4s/step - loss: 0.5692 - accuracy: 0.8577 - val_loss: 0.5139 - val_accuracy: 0.8578
#
# Epoch 00017: val_accuracy improved from 0.85763 to 0.85776, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 18/30
# 9/9 [==============================] - 36s 4s/step - loss: 0.5773 - accuracy: 0.8576 - val_loss: 0.4727 - val_accuracy: 0.8579
#
# Epoch 00018: val_accuracy improved from 0.85776 to 0.85789, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 19/30
# 9/9 [==============================] - 42s 5s/step - loss: 0.5254 - accuracy: 0.8581 - val_loss: 0.4617 - val_accuracy: 0.8582
#
# Epoch 00019: val_accuracy improved from 0.85789 to 0.85821, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 20/30
# 9/9 [==============================] - 37s 4s/step - loss: 0.4852 - accuracy: 0.8584 - val_loss: 0.3957 - val_accuracy: 0.8585
#
# Epoch 00020: val_accuracy improved from 0.85821 to 0.85850, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 21/30
# 9/9 [==============================] - 37s 4s/step - loss: 0.6153 - accuracy: 0.8582 - val_loss: 0.4835 - val_accuracy: 0.8586
#
# Epoch 00021: val_accuracy improved from 0.85850 to 0.85857, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 22/30
# 9/9 [==============================] - 37s 4s/step - loss: 0.5161 - accuracy: 0.8587 - val_loss: 0.4214 - val_accuracy: 0.8587
#
# Epoch 00022: val_accuracy improved from 0.85857 to 0.85873, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 23/30
# 9/9 [==============================] - 37s 4s/step - loss: 0.4896 - accuracy: 0.8589 - val_loss: 0.4441 - val_accuracy: 0.8592
#
# Epoch 00023: val_accuracy improved from 0.85873 to 0.85922, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 24/30
# 9/9 [==============================] - 37s 4s/step - loss: 0.5011 - accuracy: 0.8592 - val_loss: 0.4457 - val_accuracy: 0.8596
#
# Epoch 00024: val_accuracy improved from 0.85922 to 0.85958, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 25/30
# 9/9 [==============================] - 37s 4s/step - loss: 0.5163 - accuracy: 0.8599 - val_loss: 0.4187 - val_accuracy: 0.8605
#
# Epoch 00025: val_accuracy improved from 0.85958 to 0.86048, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 26/30
# 9/9 [==============================] - 37s 4s/step - loss: 0.4241 - accuracy: 0.8607 - val_loss: 0.4580 - val_accuracy: 0.8609
#
# Epoch 00026: val_accuracy improved from 0.86048 to 0.86092, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 27/30
# 9/9 [==============================] - 37s 4s/step - loss: 0.4726 - accuracy: 0.8610 - val_loss: 0.4703 - val_accuracy: 0.8613
#
# Epoch 00027: val_accuracy improved from 0.86092 to 0.86126, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 28/30
# 9/9 [==============================] - 36s 4s/step - loss: 0.4447 - accuracy: 0.8614 - val_loss: 0.4663 - val_accuracy: 0.8619
#
# Epoch 00028: val_accuracy improved from 0.86126 to 0.86186, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 29/30
# 9/9 [==============================] - 36s 4s/step - loss: 0.4169 - accuracy: 0.8621 - val_loss: 0.4015 - val_accuracy: 0.8622
#
# Epoch 00029: val_accuracy improved from 0.86186 to 0.86221, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5
# Epoch 30/30
# 9/9 [==============================] - 38s 4s/step - loss: 0.4794 - accuracy: 0.8623 - val_loss: 0.4044 - val_accuracy: 0.8625
#
# Epoch 00030: val_accuracy improved from 0.86221 to 0.86247, saving model to /content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_outseq2seq_kor/weights.h5

# %%
plot_graphs(history, 'accuracy')

# %%
plot_graphs(history, 'loss')

# %% [markdown]
# 결과확인

# %%
SAVE_FILE_NM = "weights.h5"
model.load_weights(os.path.join(DATA_OUT_PATH, MODEL_NAME, SAVE_FILE_NM))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-39-ef48c7b74ab7> in <module>()
#       1 SAVE_FILE_NM = "weights.h5"
# ----> 2 model.load_weights(os.path.join(DATA_OUT_PATH, MODEL_NAME, SAVE_FILE_NM))
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in load_weights(self, filepath, by_name, skip_mismatch, options)
#    2225           'first, then load the weights.')
#    2226     self._assert_weights_created()
# -> 2227     with h5py.File(filepath, 'r') as f:
#    2228       if 'layer_names' not in f.attrs and 'model_weights' in f:
#    2229         f = f['model_weights']
#
# /usr/local/lib/python3.7/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# /usr/local/lib/python3.7/dist-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     171         if swmr and swmr_support:
#     172             flags |= h5f.ACC_SWMR_READ
# --> 173         fid = h5f.open(name, flags, fapl=fapl)
#     174     elif mode == 'r+':
#     175         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = '/content/drive/MyDrive/2021-1/AI데이터활용교재개발/자연어처리(텐서플로,머신러닝)/code/data/chatbot/data_out/seq2seq_kor/weights.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
query = "남자친구 승진 선물로 뭐가 좋을까?"

test_index_inputs, _ = enc_processing([query], char2idx)    
predict_tokens = model.inference(test_index_inputs)
print(predict_tokens)

print(' '.join([idx2char[str(t)] for t in predict_tokens]))
